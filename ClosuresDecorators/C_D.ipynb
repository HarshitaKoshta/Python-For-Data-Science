# %%
def print_message(msg):
    def printer():
        print(msg)
    printer()    

print_message("heloooo")
# Out:
# heloooo

# %% [markdown]
# ### closure condition
# funct k andr func
#
# outer func k variable ok inner func use kr rha ho
#
# inner return kr rha ho

# %%
def print_message(msg):
    def printer():
        print(msg)
    return printer

another = print_message("heloooo")
another()
# Out:
# heloooo
