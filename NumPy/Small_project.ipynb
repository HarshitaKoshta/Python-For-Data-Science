# %% [markdown]
# ## 1️⃣ Dice Roll Simulator (NumPy Random)

# %% [markdown]
# Goal: Simulate rolling 2 dice 10,000 times and find probabilities.

# %%
import numpy as np


rolls = np.random.randint(1, 7, size=(10000, 2))
sums = rolls.sum(axis=1)

unique, counts = np.unique(sums, return_counts=True)
probabilities = counts / 10000

print(dict(zip(unique, probabilities)))
# Out:
# {np.int64(2): np.float64(0.028), np.int64(3): np.float64(0.0546), np.int64(4): np.float64(0.0887), np.int64(5): np.float64(0.1135), np.int64(6): np.float64(0.1422), np.int64(7): np.float64(0.1616), np.int64(8): np.float64(0.1357), np.int64(9): np.float64(0.108), np.int64(10): np.float64(0.086), np.int64(11): np.float64(0.0552), np.int64(12): np.float64(0.0265)}

# %%
import numpy as np
from matplotlib import image, pyplot as plt

# img = image.imread("photo.jpg")
gray = np.dot(img[..., :3], [0.299, 0.587, 0.114])

plt.imshow(gray, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 from matplotlib import image, pyplot as plt
# ----> 4 img = image.imread("photo.jpg")
#       5 gray = np.dot(img[..., :3], [0.299, 0.587, 0.114])
#       7 plt.imshow(gray, cmap='gray')
#
# File c:\Users\harsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# -> 1520 with img_open(fname) as image:
# ...

# %% [markdown]
# ## 3️⃣ Weather Data Simulation

# %%
temps = np.random.normal(loc=30, scale=3, size=30)

print("Average:", temps.mean())
print("Max:", temps.max())
print("Min:", temps.min())
